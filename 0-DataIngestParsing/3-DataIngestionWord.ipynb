# %% [markdown]
# ## Word Document Processing

# %%
from langchain_community.document_loaders import(
     Docx2txtLoader
)

# %%
word_loader = Docx2txtLoader(
    "data/word_files/proposal.docx"
)

word_document = word_loader.load()
print(f"{len(word_document)} documents")
print(word_document[0].page_content)
print("========================")
print(word_document[0].metadata)
# Out:
# 1 documents
# Project Proposal: RAG Implementation
#
# Executive Summary
#
# This proposal outlines the implementation of a Retrieval-Augmented Generation system for our organization.
#
# Objectives
#
# Key objectives include:
#
# • Improve information retrieval accuracy
#
# • Reduce response time for customer queries
#
# • Integrate with existing knowledge base
#
# Budget and Timeline
#
# Budget: $50,000
#
# Timeline: 3 months
#
# Team: 4 developers, 1 project manager
#
# Technical Requirements
#
# Required technologies:
#
# - Python 3.8+
#
# - OpenAI API access
#
# - Vector database (ChromaDB)
#
# - 16GB RAM minimum
#
# Project Phases
#
# Phase
#
# Duration
#
# Deliverables
#
# Research
#
# 2 weeks
#
# Technology evaluation report
#
# Development
#
# 8 weeks
#
# Working RAG prototype
#
# Testing
#
# 2 weeks
#
# Performance benchmarks
# ...
# {'source': 'data/word_files/proposal.docx'}

# %%
from langchain_community.document_loaders import(
     UnstructureWordDocumentLoader
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from langchain_community.document_loaders import(
#       2      UnstructureWordDocumentLoader
#       3 )
#
# ImportError: cannot import name 'UnstructureWordDocumentLoader' from 'langchain_community.document_loaders' (d:\PracticalRAG\.venv\Lib\site-packages\langchain_community\document_loaders\__init__.py)
